# %%
### Sentiment Analysis

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    phrase_id    label                                             phrase
# 0     211506  0.47222  should have been the vehicle for Chan that '' ...
# 1     173853  0.44444  the faith of the Tonga people is in every way ...
# 2     115950  0.43056                         between sappy and sanguine
# 3     164954  0.61111                                        like it did
# 4     185019  0.25000    It 's a hellish , numbing experience to watch ,

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(
    analyzer = 'word',
    lowercase = False,
    max_features=5000
)

# %%
words = df.iloc[:,2]
words = pd.Series.to_numpy(words)
labels = df.iloc[:,1]
labels = pd.Series.to_numpy(labels)

# %%
features = vectorizer.fit_transform(words)
features = features.toarray()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test  = train_test_split(
        features, 
        labels,
        train_size=0.80)

# %%
### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_model = LinearRegression()

# %%
lin_model = lin_model.fit(X=X_train, y=y_train)

# %%
y_pred = lin_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = lin_model.score(X_test, y_test)

# %%
accuracy
# Out:
# 0.4650828588814934

# %%
for i in range (0, 100): 
    print(words[i])
    print("prediction:")
    print(y_pred[i])
    print("label:")
    print(labels[i])
# Out:
# should have been the vehicle for Chan that '' The Mask '' was for Jim Carrey . Alas
# prediction:
# 0.6478105012451365
# label:
# 0.47222
# the faith of the Tonga people is in every way inferior to that of John
# prediction:
# 0.5103332567724085
# label:
# 0.44443999999999995
# between sappy and sanguine
# prediction:
# 0.7076401447162978
# label:
# 0.43056000000000005
# like it did
# prediction:
# 0.6574761830184183
# label:
# 0.61111
# It 's a hellish , numbing experience to watch ,
# prediction:
# 0.6038902293504871
# label:
# 0.25
# We get light showers of emotion a couple of times , but then -- strangely -- these wane to an inconsistent and ultimately unsatisfying drizzle .
# prediction:
# 0.4766286404783339
# label:
# 0.43056000000000005
# anyway ?
# prediction:
# 0.41722132412784485
# label:
# 0.5
# 3 '' should come with the warning '' For serious film buffs only ! ''
# prediction:
# 0.590432035956548
# label:
# 0.52778
# had a brain
# prediction:
# 0.5971892439612582
# label:
# 0.55556
# to the wit , humor and snappy dialogue of the original
# prediction:
# 0.4675146514377766
# label:
# 0.63889
# truly singular character
# prediction:
# 0.48989776720607625
# label:
# 0.56944
# are ultimately winning
# prediction:
# 0.43676182566004174
# label:
# 0.70833
# to a more mainstream audience
# prediction:
# 0.5103332567724085
# label:
# 0.5
# in all its forms
# prediction:
# 0.5433670564825371
# label:
# 0.55556
# between Sling Blade and South of Heaven , West of Hell
# prediction:
# 0.7927492851254277
# label:
# 0.41667
# has many of the things that made the first one charming
# prediction:
# 0.6084385758331134
# label:
# 0.79167
# comedy to evoke surprising poignance
# prediction:
# 0.5266677963314049
# label:
# 0.65278
# this sad-sack waste
# prediction:
# 0.516110161198025
# label:
# 0.22221999999999997
# the hot-button issue
# prediction:
# 0.6458433342269401
# label:
# 0.52778
# consumer-advice
# prediction:
# 0.9543853789219008
# label:
# 0.44443999999999995
# Other Side
# prediction:
# 0.41309338020338193
# label:
# 0.5
# 'd want something a bit more complex than We Were Soldiers to be remembered by
# prediction:
# 0.6595064015197656
# label:
# 0.41667
# eagerly and
# prediction:
# 0.34009897445448534
# label:
# 0.63889
# witty script
# prediction:
# 0.49256153959970295
# label:
# 0.65278
# in pain
# prediction:
# 0.5013190167727396
# label:
# 0.31944
# A reasonably efficient mechanism
# prediction:
# 0.78011761230916
# label:
# 0.61111
# may be wondering what all that jazz was about `` Chicago '' in 2002 .
# prediction:
# 0.6298594597788042
# label:
# 0.38889
# despair about entrapment in the maze of modern life
# prediction:
# 0.48978226171657796
# label:
# 0.44443999999999995
# enchanting ... terribly episodic and lacking the spark of imagination that might have made it an exhilarating
# prediction:
# 0.49740578946544783
# label:
# 0.27778
# A decidedly mixed bag .
# prediction:
# 0.5517225858439325
# label:
# 0.43056000000000005
# return to form for director Peter Bogdanovich
# prediction:
# 0.5103332567724085
# label:
# 0.68056
# This movie ,
# prediction:
# 0.4677899620915669
# label:
# 0.51389
# drawn with a master 's steady stroke
# prediction:
# 0.37688874858983873
# label:
# 0.81944
# to adolescent self-absorption
# prediction:
# 0.483516736514652
# label:
# 0.44443999999999995
# Mr. Shyamalan
# prediction:
# 0.5041808246045271
# label:
# 0.5
# goes bump in the night and nobody cares
# prediction:
# 0.5187500290170888
# label:
# 0.23611
# need messing with
# prediction:
# 0.5570141831758528
# label:
# 0.30556
# of genuine narrative
# prediction:
# 0.43947545062320803
# label:
# 0.55556
# such films
# prediction:
# 0.3805177504133702
# label:
# 0.5
# of greatest-hits reel
# prediction:
# 0.37582086501938633
# label:
# 0.72222
# 's hard to imagine anyone managing to steal a movie not only from charismatic rising star Jake Gyllenhaal but also from accomplished Oscar winners Susan Sarandon , Dustin Hoffman and Holly Hunter , yet newcomer Ellen Pompeo pulls off the feat with aplomb .
# prediction:
# 0.39874491508673743
# label:
# 0.86111
# Highlights
# prediction:
# 0.5054487679449965
# label:
# 0.5
# certain extent
# prediction:
# 0.580472190851955
# label:
# 0.5
# convince me that Calvin Jr. 's Barbershop represents some sort of beacon of hope in the middle of Chicago 's South Side
# prediction:
# 0.5107210652655891
# label:
# 0.58333
# Just a Kiss
# prediction:
# 0.5327875904742618
# label:
# 0.5
# the truest sense
# prediction:
# 0.5778362303067921
# label:
# 0.55556
# make us laugh
# prediction:
# 0.5103332567724085
# label:
# 0.80556
# the tar
# prediction:
# 0.3951806068106972
# label:
# 0.45833
# at a rustic
# prediction:
# 0.47461064628513033
# label:
# 0.63889
# the most aggressively nerve-wracking and screamingly neurotic
# prediction:
# 0.31936381526826835
# label:
# 0.34722
# personifying independence
# prediction:
# 0.4662893258850311
# label:
# 0.55556
# , her creepy Egyptian demigod voice is as computer processed and overproduced as it was in her music .
# prediction:
# 0.5407814644946889
# label:
# 0.27778
# -- farts , boobs , unmentionables --
# prediction:
# 0.4497014560169966
# label:
# 0.33333
# cable-sports
# prediction:
# 0.568796741206919
# label:
# 0.5
# middle-America
# prediction:
# 0.5103332567724085
# label:
# 0.5
# it hits close to home while engaging in such silliness as that snake-down-the-throat business and the inevitable shot of Schwarzenegger
# prediction:
# 0.4859584656613711
# label:
# 0.59722
# a bad taste , not only because of its bad-luck timing , but also
# prediction:
# 0.4898103612528951
# label:
# 0.22221999999999997
# the audience or the film
# prediction:
# 0.2326194356747292
# label:
# 0.5
# tinny
# prediction:
# 0.5654096962840337
# label:
# 0.41667
# remember the picture
# prediction:
# 0.4587510361373396
# label:
# 0.65278
# Conforms itself
# prediction:
# 0.7360286972386656
# label:
# 0.45833
# as a satisfying kids flck becomes increasingly implausible as it races through contrived plot points
# prediction:
# 0.4299843712123588
# label:
# 0.34722
# have done so
# prediction:
# 0.36311978563344927
# label:
# 0.33333
# of numerous minor flaws
# prediction:
# 0.7712827502317983
# label:
# 0.30556
# trek to the ` plex predisposed to like it
# prediction:
# 0.48784153667414487
# label:
# 0.61111
# pool
# prediction:
# 0.5297526895439365
# label:
# 0.44443999999999995
# how much good will the actors generate
# prediction:
# 0.5792628267450877
# label:
# 0.52778
# of failed jokes , twitchy acting , and general boorishness
# prediction:
# 0.6852153452465732
# label:
# 0.22221999999999997
# a tragic past
# prediction:
# 0.4047258065945803
# label:
# 0.27778
# adapted by Kevin Molony from Simon Leys ' novel `` The Death of Napoleon ''
# prediction:
# 0.5103332567724085
# label:
# 0.5
# inspires a continuing and deeply satisfying awareness of the best movies as monumental ` picture shows . '
# prediction:
# 0.48382443487755805
# label:
# 0.8472200000000001
# an infectious exuberance
# prediction:
# 0.5234399397997783
# label:
# 0.66667
# engrossing and grim portrait
# prediction:
# 0.49946382423010527
# label:
# 0.52778
# it stands
# prediction:
# 0.5083806934176963
# label:
# 0.5
# wrench
# prediction:
# 0.33829954966484277
# label:
# 0.5
# vibrant , and intelligent
# prediction:
# 0.836186439226157
# label:
# 0.86111
# make their way
# prediction:
# 0.4982016248150104
# label:
# 0.5
# some flawed but rather unexceptional women
# prediction:
# 0.5575982798898651
# label:
# 0.29167
# The three leads
# prediction:
# 0.4859918845862126
# label:
# 0.5
# remains prominent
# prediction:
# 0.5018712640075415
# label:
# 0.61111
# of boys
# prediction:
# 0.6038554878384508
# label:
# 0.5
# Brosnan bunch
# prediction:
# 0.5593850407729409
# label:
# 0.5
# short films
# prediction:
# 0.501097958918166
# label:
# 0.5
# as with most late-night bull sessions , eventually the content is n't nearly as captivating as the rowdy participants think it is .
# prediction:
# 0.42954125041320257
# label:
# 0.11110999999999999
# that I have n't encountered since at least Pete 's Dragon
# prediction:
# 0.516110161198025
# label:
# 0.44443999999999995
# is headed down the toilet with the ferocity of a frozen burrito after an all-night tequila bender
# prediction:
# 0.6898540306080915
# label:
# 0.11110999999999999
# There are slow and repetitive parts , but
# prediction:
# 0.5254339936690211
# label:
# 0.36111
# 's too long , too repetitive , and
# prediction:
# 0.4630371003570435
# label:
# 0.18056
# ... something appears to have been lost in the translation this time
# prediction:
# 0.49409017607990635
# label:
# 0.27778
# touching , raucously amusing ,
# prediction:
# 0.5103332567724085
# label:
# 0.81944
# delightfully quirky movie to be made from curling
# prediction:
# 0.6619568732720265
# label:
# 0.80556
# bullets ,
# prediction:
# 0.2575660902085479
# label:
# 0.47222
# Critics need a good laugh , too , and this too-extreme-for-TV rendition of the notorious MTV show delivers the outrageous , sickening , sidesplitting goods in steaming , visceral heaps
# prediction:
# 0.2947676791404953
# label:
# 0.59722
# dynamic decades
# prediction:
# 0.7047671458143725
# label:
# 0.63889
# its vistas
# prediction:
# 0.5792555426417698
# label:
# 0.5
# Quietly
# prediction:
# 0.7745661143860502
# label:
# 0.5
# neglecting character development for even one minute
# prediction:
# 0.38776642302211356
# label:
# 0.45833
# a delicate , surgical touch
# prediction:
# 0.486666318835919
# label:
# 0.70833
# Bartleby '
# prediction:
# 0.5041830865319118
# label:
# 0.59722
# manage to pronounce KOK exactly as you think they might
# prediction:
# 0.4973572310508044
# label:
# 0.51389
